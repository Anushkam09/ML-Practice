# %%
from numpy import *
import re
import feedparser
import operator

# %%
def createVocabList(dataset):
    vocab = set([])
    for document in dataset:
        vocab = vocab | set(document)
    return list(vocab)

# %%
def trainNaiveBayes(training_mat, labels):
    num_docs = len(training_mat)
    num_words = len(training_mat[0])
    p_feed = sum(labels)/float(num_docs)
    p0_num = ones(num_words)
    p1_num = ones(num_words)
    p0denom = 2.0
    p1denom = 2.0
    for i in range(num_docs):
        if labels[i] == 1:
            p1_num += training_mat[i]
            p1denom += sum(training_mat[i])
        else:
            p0_num += training_mat[i]
            p0denom += sum(training_mat[i])
    p1vect = log(p1_num/p1denom)
    p0vect = log(p0_num/p0denom)
    return p0vect, p1vect, p_feed

# %%
def classify(vec_to_classify, p0vec, p1vec, pclass1):
    p1 = sum(vec_to_classify*p1vec) + log(pclass1)
    p0 = sum(vec_to_classify*p0vec) + log(1.0 - pclass1)
    if p1 > p0:
        return 1
    return 0

# %%
def bagofWordstoVec(vocab, test_set):
    returnVec = [0]*len(vocab)
    for word in test_set:
        if word in vocab:
            returnVec[vocab.index(word)] += 1
    return returnVec

# %%
def calcMostFreq(vocab, full_text, top_x):
    freq = {}
    for token in vocab:
        freq[token] = full_text.count(token)
    sorted_freq = sorted(freq.items(), key = operator.itemgetter(1), reverse = True)
    return sorted_freq[:top_x]

# %%
def textParse(given_string):
    tokens_list = re.split(r'\W+', given_string)
    return [t.lower() for t in tokens_list if len(t) > 2]

# %%
def localwords(feed0, feed1, top_x):
    if len(feed0['entries']) == 0 or len(feed1['entries']) == 0:
        print("One or both RSS feeds are empty!")
        return
    docList = []
    classList = []
    full_text = []
    min_len = min(len(feed1['entries']), len(feed0['entries']))
    for i in range(min_len):
        wordList = textParse(feed1['entries'][i]['summary'])
        docList.append(wordList)
        full_text.extend(wordList)
        classList.append(1)
        wordList = textParse(feed0['entries'][i]['summary'])
        docList.append(wordList)
        full_text.extend(wordList)
        classList.append(0)
    vocab_list = createVocabList(docList)
    top30words = calcMostFreq(vocab_list, full_text, top_x)
    for w in top30words:
        if w[0] in vocab_list:
            vocab_list.remove(w[0])

    trainingSet = list(range(2*min_len))
    testSet = []
    for i in range(20):
        random_ind = int(random.uniform(0, len(trainingSet)))
        if random_ind in trainingSet:
            testSet.append(trainingSet[random_ind])
            del(trainingSet[random_ind])


    training_matrix = []
    training_class = []
    for i in trainingSet:
        training_matrix.append(bagofWordstoVec(vocab_list, docList[i]))
        training_class.append(classList[i])

    p0V, p1V, pSpam = trainNaiveBayes(array(training_matrix), array(training_class))
    error = 0
    for i in testSet:
        word_vector = bagofWordstoVec(vocab_list, docList[i])
        if classify(array(word_vector), p0V, p1V, pSpam) != classList[i]:
            error += 1
    print(f"The error rate is {float(error)/len(testSet)}")
    return vocab_list, p0V, p1V

# %%
def getTopWords(feed0, feed1, top_x):
    vocab_list, p0V, p1V = localwords(feed0,feed1,top_x)
    top_f0 = []
    top_f1 = []
    for i in range(len(p0V)):
        if p0V[i] > -4.5:
            top_f0.append((vocab_list[i], p0V[i]))
        if p1V[i] > -4.5:
            top_f1.append((vocab_list[i], p1V[i]))
    sorted_f1 = sorted(top_f1, key = lambda pair: pair[1], reverse = True)
    print("----------- FEED 1 -----------")
    for item in sorted_f1:
        print(item[0])

    sorted_f0 = sorted(top_f0, key = lambda pair: pair[1], reverse = True)
    print("----------- FEED 0 -----------")
    for item in sorted_f0:
        print(item[0])

# %%
nyt = feedparser.parse('https://rss.nytimes.com/services/xml/rss/nyt/Technology.xml')
bbc = feedparser.parse('https://feeds.bbci.co.uk/news/world/rss.xml')

# %%
nyt
# Out:
# {'bozo': False,
#  'entries': [{'title': 'Citing New Rules, Meta Says It Will End Political Ads in E.U.',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Technology.xml',
#     'value': 'Citing New Rules, Meta Says It Will End Political Ads in E.U.'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.nytimes.com/2025/07/25/business/meta-eu-political-ad-ban.html'},
#     {'href': 'https://www.nytimes.com/2025/07/25/business/meta-eu-political-ad-ban.html',
#      'rel': 'standout',
#      'type': 'text/html'}],
#    'link': 'https://www.nytimes.com/2025/07/25/business/meta-eu-political-ad-ban.html',
#    'id': 'https://www.nytimes.com/2025/07/25/business/meta-eu-political-ad-ban.html',
#    'guidislink': False,
#    'summary': 'Meta said political advertising would end in October, citing a forthcoming E.U. regulation that it said presented “unworkable requirements.”',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Technology.xml',
#     'value': 'Meta said political advertising would end in October, citing a forthcoming E.U. regulation that it said presented “unworkable requirements.”'},
#    'authors': [{'name': 'Isabella Kwai'}],
#    'author': 'Isabella Kwai',
#    'author_detail': {'name': 'Isabella Kwai'},
#    'published': 'Sat, 26 Jul 2025 00:52:47 +0000',
#    'published_parsed': time.struct_time(tm_year=2025, tm_mon=7, tm_mday=26, tm_hour=0, tm_min=52, tm_sec=47, tm_wday=5, tm_yday=207, tm_isdst=0),
#    'tags': [{'term': 'European Union',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_org',
#      'label': None},
#     {'term': 'Regulation and Deregulation of Industry',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Meta Platforms Inc',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_org',
#      'label': None},
#     {'term': 'Social Media',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Political Advertising',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Online Advertising',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Rumors and Misinformation',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None}],
#    'media_content': [{'height': '1800',
#      'medium': 'image',
#      'url': 'https://static01.nyt.com/images/2025/07/25/multimedia/25xp-meta-mzwt/25xp-meta-mzwt-mediumSquareAt3X.jpg',
#      'width': '1800'}],
#    'media_credit': [{'content': 'Jason Henry for The New York Times'}],
#    'credit': 'Jason Henry for The New York Times',
#    'content': [{'type': 'text/plain',
#      'language': None,
#      'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Technology.xml',
#      'value': 'The Meta headquarters in Menlo Park, Calif. Politicians and other users will still be able to share political content, “they just won’t be able to amplify this through paid advertising,” the company said.'}]},
#   {'title': 'Intel Expects Work Force to Shrink by 25,000',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Technology.xml',
#     'value': 'Intel Expects Work Force to Shrink by 25,000'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.nytimes.com/2025/07/24/technology/intel-layoffs-25000.html'},
#     {'href': 'https://www.nytimes.com/2025/07/24/technology/intel-layoffs-25000.html',
#      'rel': 'standout',
#      'type': 'text/html'}],
#    'link': 'https://www.nytimes.com/2025/07/24/technology/intel-layoffs-25000.html',
#    'id': 'https://www.nytimes.com/2025/07/24/technology/intel-layoffs-25000.html',
#    'guidislink': False,
#    'summary': 'The Silicon Valley chip company, which has been struggling, quantified the job cuts it is making as it seeks to turn its business around.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Technology.xml',
#     'value': 'The Silicon Valley chip company, which has been struggling, quantified the job cuts it is making as it seeks to turn its business around.'},
#    'authors': [{'name': 'Don Clark'}],
#    'author': 'Don Clark',
#    'author_detail': {'name': 'Don Clark'},
#    'published': 'Fri, 25 Jul 2025 01:31:39 +0000',
#    'published_parsed': time.struct_time(tm_year=2025, tm_mon=7, tm_mday=25, tm_hour=1, tm_min=31, tm_sec=39, tm_wday=4, tm_yday=206, tm_isdst=0),
#    'tags': [{'term': 'Computer Chips',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Layoffs and Job Reductions',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Computers and the Internet',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Company Reports',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Factories and Manufacturing',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Intel Corporation',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_org',
#      'label': None},
#     {'term': 'Tan, Lip-Bu',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_per',
#      'label': None}],
#    'media_content': [{'height': '1802',
#      'medium': 'image',
#      'url': 'https://static01.nyt.com/images/2025/07/24/multimedia/24-BIZ-INTEL-1-jvbz/24-BIZ-INTEL-1-jvbz-mediumSquareAt3X.jpg',
#      'width': '1800'}],
#    'media_credit': [{'content': 'Philip Cheung for The New York Times'}],
#    'credit': 'Philip Cheung for The New York Times',
#    'content': [{'type': 'text/plain',
#      'language': None,
#      'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Technology.xml',
#      'value': 'Intel had cut about 15,000 jobs last year.'}]},
#   {'title': 'The Chatbot Culture Wars Are Here',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Technology.xml',
#     'value': 'The Chatbot Culture Wars Are Here'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.nytimes.com/2025/07/23/technology/trump-ai-chatbots-bias.html'},
#     {'href': 'https://www.nytimes.com/2025/07/23/technology/trump-ai-chatbots-bias.html',
#      'rel': 'standout',
#      'type': 'text/html'}],
#    'link': 'https://www.nytimes.com/2025/07/23/technology/trump-ai-chatbots-bias.html',
#    'id': 'https://www.nytimes.com/2025/07/23/technology/trump-ai-chatbots-bias.html',
#    'guidislink': False,
#    'summary': 'Conservatives, including President Trump, are accusing A.I. companies of left-wing bias, following a playbook that worked well against social media platforms.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Technology.xml',
#     'value': 'Conservatives, including President Trump, are accusing A.I. companies of left-wing bias, following a playbook that worked well against social media platforms.'},
#    'authors': [{'name': 'Kevin Roose'}],
#    'author': 'Kevin Roose',
#    'author_detail': {'name': 'Kevin Roose'},
#    'published': 'Wed, 23 Jul 2025 23:25:06 +0000',
#    'published_parsed': time.struct_time(tm_year=2025, tm_mon=7, tm_mday=23, tm_hour=23, tm_min=25, tm_sec=6, tm_wday=2, tm_yday=204, tm_isdst=0),
#    'tags': [{'term': 'Artificial Intelligence',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Social Media',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'United States Politics and Government',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Freedom of Speech and Expression',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Computers and the Internet',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Regulation and Deregulation of Industry',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Censorship',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'OpenAI Labs',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_org',
#      'label': None},
#     {'term': 'X.ai Inc',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_org',
#      'label': None},
#     {'term': 'Google Inc',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_org',
#      'label': None},
#     {'term': 'Meta Platforms Inc',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_org',
#      'label': None},
#     {'term': 'Microsoft Corp',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_org',
#      'label': None},
#     {'term': 'Trump, Donald J',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_per',
#      'label': None},
#     {'term': 'First Amendment (US Constitution)',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None}],
#    'media_content': [{'height': '1802',
#      'medium': 'image',
#      'url': 'https://static01.nyt.com/images/2025/07/23/multimedia/ROOSE-AI-2-zhmg/ROOSE-AI-2-zhmg-mediumSquareAt3X.jpg',
#      'width': '1800'}],
#    'media_credit': [{'content': 'Kenny Holston/The New York Times'}],
#    'credit': 'Kenny Holston/The New York Times',
#    'content': [{'type': 'text/plain',
#      'language': None,
#      'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Technology.xml',
#      'value': 'On Wednesday, President Trump issued an executive order on what he called “woke A.I.”'}]},
#   {'title': 'Trump Fights ‘Woke’ A.I. + We Hear Out Our Critics',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Technology.xml',
#     'value': 'Trump Fights ‘Woke’ A.I. + We Hear Out Our Critics'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.nytimes.com/2025/07/25/podcasts/trump-fights-woke-ai-we-hear-out-our-critics.html'},
#     {'href': 'https://www.nytimes.com/2025/07/25/podcasts/trump-fights-woke-ai-we-hear-out-our-critics.html',
#      'rel': 'standout',
#      'type': 'text/html'}],
#    'link': 'https://www.nytimes.com/2025/07/25/podcasts/trump-fights-woke-ai-we-hear-out-our-critics.html',
#    'id': 'https://www.nytimes.com/2025/07/25/podcasts/trump-fights-woke-ai-we-hear-out-our-critics.html',
#    'guidislink': False,
#    'summary': '“Any historical understanding of the First Amendment would say this is just plainly unconstitutional.”',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Technology.xml',
#     'value': '“Any historical understanding of the First Amendment would say this is just plainly unconstitutional.”'},
#    'authors': [{'name': 'Kevin Roose, Casey Newton, Rachel Cohn, Whitney Jones, Jen Poyant, Katie McMurran, Dan Powell, Elisheba Ittoop, Marion Lozano and Rowan Niemisto'}],
#    'author': 'Kevin Roose, Casey Newton, Rachel Cohn, Whitney Jones, Jen Poyant, Katie McMurran, Dan Powell, Elisheba Ittoop, Marion Lozano and Rowan Niemisto',
#    'author_detail': {'name': 'Kevin Roose, Casey Newton, Rachel Cohn, Whitney Jones, Jen Poyant, Katie McMurran, Dan Powell, Elisheba Ittoop, Marion Lozano and Rowan Niemisto'},
#    'published': 'Fri, 25 Jul 2025 11:00:03 +0000',
#    'published_parsed': time.struct_time(tm_year=2025, tm_mon=7, tm_mday=25, tm_hour=11, tm_min=0, tm_sec=3, tm_wday=4, tm_yday=206, tm_isdst=0),
#    'tags': [{'term': 'Science and Technology',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'internal-open-access-audio',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None}],
#    'media_content': [{'height': '1800',
#      'medium': 'image',
#      'url': 'https://static01.nyt.com/images/2025/07/25/multimedia/25hard-fork-white-house-ai-photo-bhlt/25hard-fork-white-house-ai-photo-bhlt-mediumSquareAt3X-v3.png',
#      'width': '1800'}],
#    'media_credit': [{'content': 'Eric Lee for The New York Times; Photo Illustration by The New York Times;'}],
#    'credit': 'Eric Lee for The New York Times; Photo Illustration by The New York Times;'},
#   {'title': 'Citizen Scientists Are Accelerating Ecology Research With iNaturalist',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Technology.xml',
#     'value': 'Citizen Scientists Are Accelerating Ecology Research With iNaturalist'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.nytimes.com/2025/07/28/science/citizen-science-ecology-inaturalist.html'},
#     {'href': 'https://www.nytimes.com/2025/07/28/science/citizen-science-ecology-inaturalist.html',
#      'rel': 'standout',
#      'type': 'text/html'}],
#    'link': 'https://www.nytimes.com/2025/07/28/science/citizen-science-ecology-inaturalist.html',
#    'id': 'https://www.nytimes.com/2025/07/28/science/citizen-science-ecology-inaturalist.html',
#    'guidislink': False,
#    'summary': 'Thousands of scientific papers have used data collected by users of the platform iNaturalist, according to new research.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Technology.xml',
#     'value': 'Thousands of scientific papers have used data collected by users of the platform iNaturalist, according to new research.'},
#    'authors': [{'name': 'Emily Anthes'}],
#    'author': 'Emily Anthes',
#    'author_detail': {'name': 'Emily Anthes'},
#    'published': 'Mon, 28 Jul 2025 13:00:07 +0000',
#    'published_parsed': time.struct_time(tm_year=2025, tm_mon=7, tm_mday=28, tm_hour=13, tm_min=0, tm_sec=7, tm_wday=0, tm_yday=209, tm_isdst=0),
#    'tags': [{'term': 'your-feed-science',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Animals',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Butterflies and Moths',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Bees',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Biodiversity',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Environment',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Photography',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Flowers and Plants',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Invasive Species',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Flies',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'BioScience (Journal)',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_org',
#      'label': None},
#     {'term': 'iNaturalist (Mobile App)',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_org',
#      'label': None}]},
#   {'title': 'The Unnerving Future of A.I.-Fueled Video Games',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Technology.xml',
#     'value': 'The Unnerving Future of A.I.-Fueled Video Games'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.nytimes.com/2025/07/28/arts/video-games-artificial-intelligence.html'},
#     {'href': 'https://www.nytimes.com/2025/07/28/arts/video-games-artificial-intelligence.html',
#      'rel': 'standout',
#      'type': 'text/html'}],
#    'link': 'https://www.nytimes.com/2025/07/28/arts/video-games-artificial-intelligence.html',
#    'id': 'https://www.nytimes.com/2025/07/28/arts/video-games-artificial-intelligence.html',
#    'guidislink': False,
#    'summary': 'Game designers have used artificial intelligence since the 1980s. But digital characters demonstrating self-awareness is a far cry from the ghosts chasing Pac-Man.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Technology.xml',
#     'value': 'Game designers have used artificial intelligence since the 1980s. But digital characters demonstrating self-awareness is a far cry from the ghosts chasing Pac-Man.'},
#    'authors': [{'name': 'Zachary Small'}],
#    'author': 'Zachary Small',
#    'author_detail': {'name': 'Zachary Small'},
#    'published': 'Mon, 28 Jul 2025 09:00:06 +0000',
#    'published_parsed': time.struct_time(tm_year=2025, tm_mon=7, tm_mday=28, tm_hour=9, tm_min=0, tm_sec=6, tm_wday=0, tm_yday=209, tm_isdst=0),
#    'tags': [{'term': 'Computer and Video Games',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Artificial Intelligence',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Game Developers Conference',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Microsoft Corp',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_org',
#      'label': None},
#     {'term': 'Amazon.com Inc',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_org',
#      'label': None},
#     {'term': 'Google Inc',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_org',
#      'label': None},
#     {'term': 'Nintendo Co Ltd',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_org',
#      'label': None},
#     {'term': 'Sony Corporation',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_org',
#      'label': None},
#     {'term': 'OpenAI Labs',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_org',
#      'label': None}]},
#   {'title': 'William J. Rutter, Biotech Pioneer of Gene-Based Medicine, Dies at 97',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Technology.xml',
#     'value': 'William J. Rutter, Biotech Pioneer of Gene-Based Medicine, Dies at 97'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.nytimes.com/2025/07/27/science/william-j-rutter-dead.html'},
#     {'href': 'https://www.nytimes.com/2025/07/27/science/william-j-rutter-dead.html',
#      'rel': 'standout',
#      'type': 'text/html'}],
#    'link': 'https://www.nytimes.com/2025/07/27/science/william-j-rutter-dead.html',
#    'id': 'https://www.nytimes.com/2025/07/27/science/william-j-rutter-dead.html',
#    'guidislink': False,
#    'summary': 'His company, the Chiron Corporation, contributed important scientific discoveries toward treatments for H.I.V., hepatitis B, diabetes and more.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Technology.xml',
#     'value': 'His company, the Chiron Corporation, contributed important scientific discoveries toward treatments for H.I.V., hepatitis B, diabetes and more.'},
#    'authors': [{'name': 'Trip Gabriel'}],
#    'author': 'Trip Gabriel',
#    'author_detail': {'name': 'Trip Gabriel'},
#    'published': 'Sun, 27 Jul 2025 16:28:04 +0000',
#    'published_parsed': time.struct_time(tm_year=2025, tm_mon=7, tm_mday=27, tm_hour=16, tm_min=28, tm_sec=4, tm_wday=6, tm_yday=208, tm_isdst=0),
#    'tags': [{'term': 'Rutter, William J',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_per',
#      'label': None},
#     {'term': 'Deaths (Obituaries)',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Biotechnology and Bioengineering',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Chiron Corporation',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_org',
#      'label': None},
#     {'term': 'Genetic Engineering',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Research',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'San Francisco Bay Area (Calif)',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_geo',
#      'label': None},
#     {'term': 'Colleges and Universities',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'University of California, San Francisco',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_org',
#      'label': None}],
#    'media_content': [{'height': '1120',
#      'medium': 'image',
#      'url': 'https://static01.nyt.com/images/2025/08/24/multimedia/24Rutter-01-bzgp/24Rutter-01-bzgp-mediumSquareAt3X.jpg',
#      'width': '1121'}],
#    'media_credit': [{'content': 'Liz Hafalia/San Francisco Chronicle, via Associated Press'}],
#    'credit': 'Liz Hafalia/San Francisco Chronicle, via Associated Press',
#    'content': [{'type': 'text/plain',
#      'language': None,
#      'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Technology.xml',
#      'value': 'William J. Rutter in 2007. He was chairman of the board of Chiron, which specialized in recombinant DNA technology, also known as gene splicing.'}]},
#   {'title': 'What to Know About the Hack at Tea, an App Where Women Share Red Flags About Men',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Technology.xml',
#     'value': 'What to Know About the Hack at Tea, an App Where Women Share Red Flags About Men'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.nytimes.com/2025/07/26/us/tea-safety-dating-app-hack.html'},
#     {'href': 'https://www.nytimes.com/2025/07/26/us/tea-safety-dating-app-hack.html',
#      'rel': 'standout',
#      'type': 'text/html'}],
#    'link': 'https://www.nytimes.com/2025/07/26/us/tea-safety-dating-app-hack.html',
#    'id': 'https://www.nytimes.com/2025/07/26/us/tea-safety-dating-app-hack.html',
#    'guidislink': False,
#    'summary': 'A data breach exposed photos and ID cards of women who signed up for a fast-growing app for women to share details of men they might date.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Technology.xml',
#     'value': 'A data breach exposed photos and ID cards of women who signed up for a fast-growing app for women to share details of men they might date.'},
#    'authors': [{'name': 'Isabella Kwai'}],
#    'author': 'Isabella Kwai',
#    'author_detail': {'name': 'Isabella Kwai'},
#    'published': 'Sat, 26 Jul 2025 15:03:33 +0000',
#    'published_parsed': time.struct_time(tm_year=2025, tm_mon=7, tm_mday=26, tm_hour=15, tm_min=3, tm_sec=33, tm_wday=5, tm_yday=207, tm_isdst=0),
#    'tags': [{'term': 'Tea Dating Advice (Mobile App)',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_org',
#      'label': None},
#     {'term': 'Dating and Relationships',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Mobile Applications',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Women and Girls',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Identification Devices',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Cyberattacks and Hackers',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None}],
#    'media_content': [{'height': '1801',
#      'medium': 'image',
#      'url': 'https://static01.nyt.com/images/2025/07/26/multimedia/26xp-tea-hack-wtfb/26xp-tea-hack-wtfb-mediumSquareAt3X.jpg',
#      'width': '1800'}],
#    'media_credit': [{'content': 'Associated Press'}],
#    'credit': 'Associated Press',
#    'content': [{'type': 'text/plain',
#      'language': None,
#      'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Technology.xml',
#      'value': 'Tea Dating Advice, an app that allows women to share information about the men they might date, surged in popularity this week.'}]},
#   {'title': 'In the Latest Space Race, It’s China vs. SpaceX',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Technology.xml',
#     'value': 'In the Latest Space Race, It’s China vs. SpaceX'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.nytimes.com/video/technology/100000010290263/china-starlink-space-race.html'},
#     {'href': 'https://www.nytimes.com/video/technology/100000010290263/china-starlink-space-race.html',
#      'rel': 'standout',
#      'type': 'text/html'}],
#    'link': 'https://www.nytimes.com/video/technology/100000010290263/china-starlink-space-race.html',
#    'id': 'https://www.nytimes.com/video/technology/100000010290263/china-starlink-space-race.html',
#    'guidislink': False,
#    'summary': 'China has made it a national priority to catch up with SpaceX’s nearly 8,000 Starlink internet-providing satellites in low-Earth orbit, which it regards as a military threat. Despite successes in other parts of its space program, China has just 124 internet-providing satellites in low-Earth orbit. Selam Gebrekidian, an investigative reporter for The New York Times, explains why China is lagging behind in this new space race.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Technology.xml',
#     'value': 'China has made it a national priority to catch up with SpaceX’s nearly 8,000 Starlink internet-providing satellites in low-Earth orbit, which it regards as a military threat. Despite successes in other parts of its space program, China has just 124 internet-providing satellites in low-Earth orbit. Selam Gebrekidian, an investigative reporter for The New York Times, explains why China is lagging behind in this new space race.'},
#    'authors': [{'name': 'Selam Gebrekidan, Nikolay Nikolov, Jon Hazell, Laura Salaberry and Malika Khurana'}],
#    'author': 'Selam Gebrekidan, Nikolay Nikolov, Jon Hazell, Laura Salaberry and Malika Khurana',
#    'author_detail': {'name': 'Selam Gebrekidan, Nikolay Nikolov, Jon Hazell, Laura Salaberry and Malika Khurana'},
#    'published': 'Fri, 25 Jul 2025 02:54:42 +0000',
#    'published_parsed': time.struct_time(tm_year=2025, tm_mon=7, tm_mday=25, tm_hour=2, tm_min=54, tm_sec=42, tm_wday=4, tm_yday=206, tm_isdst=0),
#    'tags': [{'term': 'Satellites',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Space and Astronomy',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Earth',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Private Spaceflight',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Defense and Military Forces',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Space Exploration Technologies Corp',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_org',
#      'label': None},
#     {'term': 'Starlink Satellite Constellation (SpaceX)',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_org',
#      'label': None},
#     {'term': 'China',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_geo',
#      'label': None}]},
#   {'title': 'Trump’s A.I. Challenge: Focus on Weapon Concerns or Woke-ism?',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Technology.xml',
#     'value': 'Trump’s A.I. Challenge: Focus on Weapon Concerns or Woke-ism?'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.nytimes.com/2025/07/23/us/politics/trump-ai-nuclear-weapons.html'},
#     {'href': 'https://www.nytimes.com/2025/07/23/us/politics/trump-ai-nuclear-weapons.html',
#      'rel': 'standout',
#      'type': 'text/html'}],
#    'link': 'https://www.nytimes.com/2025/07/23/us/politics/trump-ai-nuclear-weapons.html',
#    'id': 'https://www.nytimes.com/2025/07/23/us/politics/trump-ai-nuclear-weapons.html',
#    'guidislink': False,
#    'summary': 'In the Biden era, the government feared AI models would guide the spread of chemical, biological or nuclear weapons. President Trump signed an order on “Preventing Woke A.I. in the Federal Government.”',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Technology.xml',
#     'value': 'In the Biden era, the government feared AI models would guide the spread of chemical, biological or nuclear weapons. President Trump signed an order on “Preventing Woke A.I. in the Federal Government.”'},
#    'authors': [{'name': 'David E. Sanger'}],
#    'author': 'David E. Sanger',
#    'author_detail': {'name': 'David E. Sanger'},
#    'published': 'Thu, 24 Jul 2025 00:32:23 +0000',
#    'published_parsed': time.struct_time(tm_year=2025, tm_mon=7, tm_mday=24, tm_hour=0, tm_min=32, tm_sec=23, tm_wday=3, tm_yday=205, tm_isdst=0),
#    'tags': [{'term': 'Artificial Intelligence',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Trump, Donald J',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_per',
#      'label': None},
#     {'term': 'Biden, Joseph R Jr',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_per',
#      'label': None},
#     {'term': 'United States Politics and Government',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Regulation and Deregulation of Industry',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Terrorism',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Biological and Chemical Warfare',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Nuclear Weapons',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'United States International Relations',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'China',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_geo',
#      'label': None}],
#    'media_content': [{'height': '1802',
#      'medium': 'image',
#      'url': 'https://static01.nyt.com/images/2025/07/23/multimedia/23dc-AI-ASSESS-mbgf/23dc-AI-ASSESS-mbgf-mediumSquareAt3X.jpg',
#      'width': '1800'}],
#    'media_credit': [{'content': 'Kenny Holston/The New York Times'}],
#    'credit': 'Kenny Holston/The New York Times',
#    'content': [{'type': 'text/plain',
#      'language': None,
#      'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Technology.xml',
#      'value': 'President Trump’s executive action bars the U.S. government from buying, using or promoting A.I. models that contradict the views of the president or his supporters.'}]},
#   {'title': 'Alphabet Earnings Show 14% Revenue Increase as Google Faces A.I. Competition',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Technology.xml',
#     'value': 'Alphabet Earnings Show 14% Revenue Increase as Google Faces A.I. Competition'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.nytimes.com/2025/07/23/technology/alphabet-google-earnings-ai.html'},
#     {'href': 'https://www.nytimes.com/2025/07/23/technology/alphabet-google-earnings-ai.html',
#      'rel': 'standout',
#      'type': 'text/html'}],
#    'link': 'https://www.nytimes.com/2025/07/23/technology/alphabet-google-earnings-ai.html',
#    'id': 'https://www.nytimes.com/2025/07/23/technology/alphabet-google-earnings-ai.html',
#    'guidislink': False,
#    'summary': 'Google’s parent company, which is facing aggressive competition in its core search business from A.I. chatbots, also posted a double-digit profit increase.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Technology.xml',
#     'value': 'Google’s parent company, which is facing aggressive competition in its core search business from A.I. chatbots, also posted a double-digit profit increase.'},
#    'authors': [{'name': 'David Streitfeld'}],
#    'author': 'David Streitfeld',
#    'author_detail': {'name': 'David Streitfeld'},
#    'published': 'Wed, 23 Jul 2025 22:44:02 +0000',
#    'published_parsed': time.struct_time(tm_year=2025, tm_mon=7, tm_mday=23, tm_hour=22, tm_min=44, tm_sec=2, tm_wday=2, tm_yday=204, tm_isdst=0),
#    'tags': [{'term': 'Artificial Intelligence',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Search Engines',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Antitrust Laws and Competition Issues',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Company Reports',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Computers and the Internet',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'ChatGPT',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Alphabet Inc',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_org',
#      'label': None},
#     {'term': 'Google Inc',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_org',
#      'label': None}],
#    'media_content': [{'height': '1800',
#      'medium': 'image',
#      'url': 'https://static01.nyt.com/images/2025/07/23/multimedia/23biz-google-earnings-bltw/23biz-google-earnings-bltw-mediumSquareAt3X.jpg',
#      'width': '1800'}],
#    'media_credit': [{'content': 'Mike Kai Chen for The New York Times'}],
#    'credit': 'Mike Kai Chen for The New York Times',
#    'content': [{'type': 'text/plain',
#      'language': None,
#      'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Technology.xml',
#      'value': 'Google’s developer conference in May. Alphabet, Google’s parent company, reported second-quarter results on Wednesday.'}]},
#   {'title': 'A.I. May Be the Future, but First It Has to Study Ancient Roman History',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Technology.xml',
#     'value': 'A.I. May Be the Future, but First It Has to Study Ancient Roman History'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.nytimes.com/2025/07/23/science/ai-history-ancient-rome-google-deepmind.html'},
#     {'href': 'https://www.nytimes.com/2025/07/23/science/ai-history-ancient-rome-google-deepmind.html',
#      'rel': 'standout',
#      'type': 'text/html'}],
#    'link': 'https://www.nytimes.com/2025/07/23/science/ai-history-ancient-rome-google-deepmind.html',
#    'id': 'https://www.nytimes.com/2025/07/23/science/ai-history-ancient-rome-google-deepmind.html',
#    'guidislink': False,
#    'summary': 'A software model from Google DeepMind put a more precise date on an important Latin text credited to a Roman emperor as a demonstration of its capabilities.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Technology.xml',
#     'value': 'A software model from Google DeepMind put a more precise date on an important Latin text credited to a Roman emperor as a demonstration of its capabilities.'},
#    'authors': [{'name': 'William J. Broad'}],
#    'author': 'William J. Broad',
#    'author_detail': {'name': 'William J. Broad'},
#    'published': 'Wed, 23 Jul 2025 18:44:48 +0000',
#    'published_parsed': time.struct_time(tm_year=2025, tm_mon=7, tm_mday=23, tm_hour=18, tm_min=44, tm_sec=48, tm_wday=2, tm_yday=204, tm_isdst=0),
#    'tags': [{'term': 'Artificial Intelligence',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'History (Academic Subject)',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Roman Civilization',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'DeepMind Technologies Ltd',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_org',
#      'label': None},
#     {'term': 'Google Inc',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_org',
#      'label': None},
#     {'term': 'Nature (Journal)',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_org',
#      'label': None},
#     {'term': 'Research',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'your-feed-science',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None}],
#    'media_content': [{'height': '1800',
#      'medium': 'image',
#      'url': 'https://static01.nyt.com/images/2025/07/23/science/23HS-sci-ai-history/23HS-sci-ai-history-mediumSquareAt3X.jpg',
#      'width': '1800'}],
#    'media_credit': [{'content': 'Ivan Vdovin/Alamy'}],
#    'credit': 'Ivan Vdovin/Alamy',
#    'content': [{'type': 'text/plain',
#      'language': None,
#      'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Technology.xml',
#      'value': 'The Monumentum Ancyranum, Temple of Augustus and Rome, in Ankara, Turkey, which holds the most complete text of the Res Gestae Divi Augusti. An A.I. program has pinpointed a likely date of the inscription.'}]},
#   {'title': 'Meta Unveils Wristband For Controlling Computers With Hand Gestures',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Technology.xml',
#     'value': 'Meta Unveils Wristband For Controlling Computers With Hand Gestures'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.nytimes.com/2025/07/23/science/meta-computer-wristband-reardon.html'},
#     {'href': 'https://www.nytimes.com/2025/07/23/science/meta-computer-wristband-reardon.html',
#      'rel': 'standout',
#      'type': 'text/html'}],
#    'link': 'https://www.nytimes.com/2025/07/23/science/meta-computer-wristband-reardon.html',
#    'id': 'https://www.nytimes.com/2025/07/23/science/meta-computer-wristband-reardon.html',
#    'guidislink': False,
#    'summary': 'When you write your name in the air, you can see the letters appear on your smartphone.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Technology.xml',
#     'value': 'When you write your name in the air, you can see the letters appear on your smartphone.'},
#    'authors': [{'name': 'Cade Metz'}],
#    'author': 'Cade Metz',
#    'author_detail': {'name': 'Cade Metz'},
#    'published': 'Wed, 23 Jul 2025 15:00:18 +0000',
#    'published_parsed': time.struct_time(tm_year=2025, tm_mon=7, tm_mday=23, tm_hour=15, tm_min=0, tm_sec=18, tm_wday=2, tm_yday=204, tm_isdst=0),
#    'tags': [{'term': 'Computers and the Internet',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Brain',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Smartphones',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Artificial Intelligence',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Medical Devices',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Disabilities',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Muscles',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Prostheses',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Nerves and Nervous System',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Meta Platforms Inc',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_org',
#      'label': None},
#     {'term': 'Nature (Journal)',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_org',
#      'label': None}]},
#   {'title': 'Trump Plans to Give A.I. Developers a Free Hand',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Technology.xml',
#     'value': 'Trump Plans to Give A.I. Developers a Free Hand'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.nytimes.com/2025/07/23/technology/trump-ai-executive-orders.html'},
#     {'href': 'https://www.nytimes.com/2025/07/23/technology/trump-ai-executive-orders.html',
#      'rel': 'standout',
#      'type': 'text/html'}],
#    'link': 'https://www.nytimes.com/2025/07/23/technology/trump-ai-executive-orders.html',
#    'id': 'https://www.nytimes.com/2025/07/23/technology/trump-ai-executive-orders.html',
#    'guidislink': False,
#    'summary': 'With executive orders and an “A.I. Action Plan” to promote American dominance of the technology, President Trump declared that the United States needed to win the A.I. race.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Technology.xml',
#     'value': 'With executive orders and an “A.I. Action Plan” to promote American dominance of the technology, President Trump declared that the United States needed to win the A.I. race.'},
#    'authors': [{'name': 'David McCabe and Cecilia Kang'}],
#    'author': 'David McCabe and Cecilia Kang',
#    'author_detail': {'name': 'David McCabe and Cecilia Kang'},
#    'published': 'Wed, 23 Jul 2025 23:24:27 +0000',
#    'published_parsed': time.struct_time(tm_year=2025, tm_mon=7, tm_mday=23, tm_hour=23, tm_min=24, tm_sec=27, tm_wday=2, tm_yday=204, tm_isdst=0),
#    'tags': [{'term': 'Artificial Intelligence',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Regulation and Deregulation of Industry',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Innovation',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Trump, Donald J',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_per',
#      'label': None},
#     {'term': 'United States Politics and Government',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Executive Orders and Memorandums',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Computers and the Internet',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None}],
#    'media_content': [{'height': '1800',
#      'medium': 'image',
#      'url': 'https://static01.nyt.com/images/2025/07/23/multimedia/23biz-trump-ai-2-cbft/23biz-trump-ai-2-cbft-mediumSquareAt3X.jpg',
#      'width': '1800'}],
#    'media_credit': [{'content': 'Kenny Holston/The New York Times'}],
#    'credit': 'Kenny Holston/The New York Times',
#    'content': [{'type': 'text/plain',
#      'language': None,
#      'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Technology.xml',
#      'value': 'President Trump detailed a new “A.I. Action Plan,” which contains policy guidelines to encourage the growth of the artificial intelligence industry in the United States.'}]},
#   {'title': 'Tesla Earnings Show Falling Profit as Car Sales Slow',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Technology.xml',
#     'value': 'Tesla Earnings Show Falling Profit as Car Sales Slow'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.nytimes.com/2025/07/23/business/tesla-earnings-elon-musk.html'},
#     {'href': 'https://www.nytimes.com/2025/07/23/business/tesla-earnings-elon-musk.html',
#      'rel': 'standout',
#      'type': 'text/html'}],
#    'link': 'https://www.nytimes.com/2025/07/23/business/tesla-earnings-elon-musk.html',
#    'id': 'https://www.nytimes.com/2025/07/23/business/tesla-earnings-elon-musk.html',
#    'guidislink': False,
#    'summary': 'Elon Musk has said robotaxis are the company’s future, but most revenue still comes from cars.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Technology.xml',
#     'value': 'Elon Musk has said robotaxis are the company’s future, but most revenue still comes from cars.'},
#    'authors': [{'name': 'Jack Ewing'}],
#    'author': 'Jack Ewing',
#    'author_detail': {'name': 'Jack Ewing'},
#    'published': 'Wed, 23 Jul 2025 22:58:12 +0000',
#    'published_parsed': time.struct_time(tm_year=2025, tm_mon=7, tm_mday=23, tm_hour=22, tm_min=58, tm_sec=12, tm_wday=2, tm_yday=204, tm_isdst=0),
#    'tags': [{'term': 'Electric and Hybrid Vehicles',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Company Reports',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Prices (Fares, Fees and Rates)',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Automobiles',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'United States Politics and Government',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Driverless and Semiautonomous Vehicles',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'International Trade and World Market',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Customs (Tariff)',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Law and Legislation',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'BYD Co Ltd',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_org',
#      'label': None},
#     {'term': 'Tesla Motors Inc',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_org',
#      'label': None},
#     {'term': 'Musk, Elon',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_per',
#      'label': None},
#     {'term': 'Trump, Donald J',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_per',
#      'label': None},
#     {'term': 'China',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_geo',
#      'label': None},
#     {'term': 'Austin (Tex)',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_geo',
#      'label': None},
#     {'term': 'Europe',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_geo',
#      'label': None}],
#    'media_content': [{'height': '1800',
#      'medium': 'image',
#      'url': 'https://static01.nyt.com/images/2025/07/23/multimedia/23biz-tesla-earnings-ftcm/23biz-tesla-earnings-ftcm-mediumSquareAt3X.jpg',
#      'width': '1800'}],
# ...
#   {'title': 'William H. Neukom, Microsoft Lawyer Who Led Antitrust Fight, Dies at 83',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Technology.xml',
#     'value': 'William H. Neukom, Microsoft Lawyer Who Led Antitrust Fight, Dies at 83'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.nytimes.com/2025/07/22/business/william-h-neukom-dead.html'},
#     {'href': 'https://www.nytimes.com/2025/07/22/business/william-h-neukom-dead.html',
#      'rel': 'standout',
#      'type': 'text/html'}],
#    'link': 'https://www.nytimes.com/2025/07/22/business/william-h-neukom-dead.html',
#    'id': 'https://www.nytimes.com/2025/07/22/business/william-h-neukom-dead.html',
#    'guidislink': False,
#    'summary': 'In the 1990s, the U.S. called Microsoft a bullying monopoly and sought to rein it in. The company lost in a landmark decision, but emerged intact.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Technology.xml',
#     'value': 'In the 1990s, the U.S. called Microsoft a bullying monopoly and sought to rein it in. The company lost in a landmark decision, but emerged intact.'},
#    'authors': [{'name': 'Steve Lohr'}],
#    'author': 'Steve Lohr',
#    'author_detail': {'name': 'Steve Lohr'},
#    'published': 'Wed, 23 Jul 2025 05:04:38 +0000',
#    'published_parsed': time.struct_time(tm_year=2025, tm_mon=7, tm_mday=23, tm_hour=5, tm_min=4, tm_sec=38, tm_wday=2, tm_yday=204, tm_isdst=0),
#    'tags': [{'term': 'Neukom, William H',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_per',
#      'label': None},
#     {'term': 'Computers and the Internet',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Antitrust Laws and Competition Issues',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Software',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Decisions and Verdicts',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Deaths (Obituaries)',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Legal Profession',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Microsoft Corp',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_org',
#      'label': None}],
#    'media_content': [{'height': '1798',
#      'medium': 'image',
#      'url': 'https://static01.nyt.com/images/2025/07/21/multimedia/21Neukom--02-kcpb/21Neukom--02-kcpb-mediumSquareAt3X.jpg',
#      'width': '1800'}],
#    'media_credit': [{'content': 'Earl Wilson/The New York Times'}],
#    'credit': 'Earl Wilson/The New York Times',
#    'content': [{'type': 'text/plain',
#      'language': None,
#      'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Technology.xml',
#      'value': 'Mr. Neukom in 2011. A Dartmouth graduate, he earned his law degree at Stanford and initially clerked in a State Supreme Court in Seattle.'}]},
#   {'title': 'Mike Lynch’s Estate Ordered to Pay Hewlett Packard $945 Million',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Technology.xml',
#     'value': 'Mike Lynch’s Estate Ordered to Pay Hewlett Packard $945 Million'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.nytimes.com/2025/07/22/business/dealbook/mike-lynch-hp.html'},
#     {'href': 'https://www.nytimes.com/2025/07/22/business/dealbook/mike-lynch-hp.html',
#      'rel': 'standout',
#      'type': 'text/html'}],
#    'link': 'https://www.nytimes.com/2025/07/22/business/dealbook/mike-lynch-hp.html',
#    'id': 'https://www.nytimes.com/2025/07/22/business/dealbook/mike-lynch-hp.html',
#    'guidislink': False,
#    'summary': 'The technology giant had accused the British mogul, who died last year when his yacht sank, of fraud in the sale of his company in 2011.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Technology.xml',
#     'value': 'The technology giant had accused the British mogul, who died last year when his yacht sank, of fraud in the sale of his company in 2011.'},
#    'authors': [{'name': 'Michael J. de la Merced'}],
#    'author': 'Michael J. de la Merced',
#    'author_detail': {'name': 'Michael J. de la Merced'},
#    'published': 'Tue, 22 Jul 2025 19:37:36 +0000',
#    'published_parsed': time.struct_time(tm_year=2025, tm_mon=7, tm_mday=22, tm_hour=19, tm_min=37, tm_sec=36, tm_wday=1, tm_yday=203, tm_isdst=0),
#    'tags': [{'term': 'Decisions and Verdicts',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Mergers, Acquisitions and Divestitures',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Wills and Estates',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Lynch, Michael Richard (1965- )',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_per',
#      'label': None},
#     {'term': 'Hewlett Packard Enterprise Company',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_org',
#      'label': None},
#     {'term': 'Hewlett-Packard Company',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_org',
#      'label': None},
#     {'term': 'Autonomy Corp PLC',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_org',
#      'label': None},
#     {'term': 'Compensation for Damages (Law)',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Suits and Litigation (Civil)',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Frauds and Swindling',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None}]},
#   {'title': 'Tesla Driver Testifies Autopilot Failed to Prevent Fatal Crash',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Technology.xml',
#     'value': 'Tesla Driver Testifies Autopilot Failed to Prevent Fatal Crash'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.nytimes.com/2025/07/21/business/tesla-trial-autopilot.html'},
#     {'href': 'https://www.nytimes.com/2025/07/21/business/tesla-trial-autopilot.html',
#      'rel': 'standout',
#      'type': 'text/html'}],
#    'link': 'https://www.nytimes.com/2025/07/21/business/tesla-trial-autopilot.html',
#    'id': 'https://www.nytimes.com/2025/07/21/business/tesla-trial-autopilot.html',
#    'guidislink': False,
#    'summary': 'The driver gave testimony in a federal trial about Tesla’s role in a 2019 accident that killed a woman in Florida.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Technology.xml',
#     'value': 'The driver gave testimony in a federal trial about Tesla’s role in a 2019 accident that killed a woman in Florida.'},
#    'authors': [{'name': 'Neal E. Boudette'}],
#    'author': 'Neal E. Boudette',
#    'author_detail': {'name': 'Neal E. Boudette'},
#    'published': 'Tue, 22 Jul 2025 16:03:54 +0000',
#    'published_parsed': time.struct_time(tm_year=2025, tm_mon=7, tm_mday=22, tm_hour=16, tm_min=3, tm_sec=54, tm_wday=1, tm_yday=203, tm_isdst=0),
#    'tags': [{'term': 'Driverless and Semiautonomous Vehicles',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Traffic Accidents and Safety',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Suits and Litigation (Civil)',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Deaths (Fatalities)',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Tesla Motors Inc',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_org',
#      'label': None},
#     {'term': 'Musk, Elon',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_per',
#      'label': None},
#     {'term': 'Electric and Hybrid Vehicles',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Brakes',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Driver Distraction and Fatigue',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Automobile Safety Features and Defects',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Recalls and Bans of Products',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'McGee, George Brian',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_per',
#      'label': None},
#     {'term': 'Benavides Leon, Naibel (d 2019)',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_per',
#      'label': None},
#     {'term': 'Florida',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_geo',
#      'label': None}],
#    'media_content': [{'height': '380',
#      'medium': 'image',
#      'url': 'https://static01.nyt.com/images/2021/08/12/business/21biz-tesla-trial/00tesla-01-mediumSquareAt3X.jpg',
#      'width': '381'}],
#    'media_credit': [{'content': "via Monroe County Sheriff's Department"}],
#    'credit': "via Monroe County Sheriff's Department",
#    'content': [{'type': 'text/plain',
#      'language': None,
#      'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Technology.xml',
#      'value': 'The accident scene in Key Largo, Fla., in 2019 after a Tesla Model S crashed into a parked vehicle.'}]},
#   {'title': 'Google A.I. System Wins Gold In International Math Olympiad',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Technology.xml',
#     'value': 'Google A.I. System Wins Gold In International Math Olympiad'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.nytimes.com/2025/07/21/technology/google-ai-international-mathematics-olympiad.html'},
#     {'href': 'https://www.nytimes.com/2025/07/21/technology/google-ai-international-mathematics-olympiad.html',
#      'rel': 'standout',
#      'type': 'text/html'}],
#    'link': 'https://www.nytimes.com/2025/07/21/technology/google-ai-international-mathematics-olympiad.html',
#    'id': 'https://www.nytimes.com/2025/07/21/technology/google-ai-international-mathematics-olympiad.html',
#    'guidislink': False,
#    'summary': 'OpenAI said it, too, had built a system that achieved similar results.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Technology.xml',
#     'value': 'OpenAI said it, too, had built a system that achieved similar results.'},
#    'authors': [{'name': 'Cade Metz'}],
#    'author': 'Cade Metz',
#    'author_detail': {'name': 'Cade Metz'},
#    'published': 'Mon, 21 Jul 2025 20:52:14 +0000',
#    'published_parsed': time.struct_time(tm_year=2025, tm_mon=7, tm_mday=21, tm_hour=20, tm_min=52, tm_sec=14, tm_wday=0, tm_yday=202, tm_isdst=0),
#    'tags': [{'term': 'Artificial Intelligence',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Computers and the Internet',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Mathematics',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Research',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/des',
#      'label': None},
#     {'term': 'Google Inc',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_org',
#      'label': None},
#     {'term': 'OpenAI Labs',
#      'scheme': 'http://www.nytimes.com/namespaces/keywords/nyt_org',
#      'label': None}],
#    'media_content': [{'height': '1800',
#      'medium': 'image',
#      'url': 'https://static01.nyt.com/images/2025/07/21/business/21BIZ-AI-MATH/21BIZ-AI-MATH-mediumSquareAt3X.jpg',
#      'width': '1800'}],
#    'media_credit': [{'content': 'via Google DeepMind'}],
#    'credit': 'via Google DeepMind',
#    'content': [{'type': 'text/plain',
#      'language': None,
#      'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Technology.xml',
#      'value': 'Google DeepMind representatives at the International Mathematical Olympiad on Australia’s Sunshine Coast. From left, Junehyuk Jung, Thang Luong, Dawsen Hwang and Yuri Chervonyi.'}]}],
#  'feed': {'title': 'NYT > Technology',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Technology.xml',
#    'value': 'NYT > Technology'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'https://www.nytimes.com/section/technology'},
#    {'href': 'https://rss.nytimes.com/services/xml/rss/nyt/Technology.xml',
#     'rel': 'self',
#     'type': 'application/rss+xml'}],
#   'link': 'https://www.nytimes.com/section/technology',
#   'subtitle': '',
#   'subtitle_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Technology.xml',
#    'value': ''},
#   'language': 'en-us',
#   'rights': 'Copyright 2025 The New York Times Company',
#   'rights_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Technology.xml',
#    'value': 'Copyright 2025 The New York Times Company'},
#   'updated': 'Mon, 28 Jul 2025 14:17:45 +0000',
#   'updated_parsed': time.struct_time(tm_year=2025, tm_mon=7, tm_mday=28, tm_hour=14, tm_min=17, tm_sec=45, tm_wday=0, tm_yday=209, tm_isdst=0),
#   'published': 'Mon, 28 Jul 2025 13:00:07 +0000',
#   'published_parsed': time.struct_time(tm_year=2025, tm_mon=7, tm_mday=28, tm_hour=13, tm_min=0, tm_sec=7, tm_wday=0, tm_yday=209, tm_isdst=0),
#   'image': {'title': 'NYT > Technology',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://rss.nytimes.com/services/xml/rss/nyt/Technology.xml',
#     'value': 'NYT > Technology'},
#    'href': 'https://static01.nyt.com/images/misc/NYT_logo_rss_250x40.png',
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.nytimes.com/section/technology'}],
#    'link': 'https://www.nytimes.com/section/technology'}},
#  'headers': {'connection': 'close',
#   'content-length': '7671',
#   'access-control-allow-headers': 'Accept, Content-Type, X-Forwarded-For, X-Prototype-Version, X-Requested-With',
#   'access-control-allow-methods': 'GET, OPTIONS',
#   'access-control-allow-origin': '*',
#   'access-control-expose-headers': 'Content-Length, X-JSON',
#   'cache-control': 'public, max-age=300',
#   'content-type': 'application/xml',
#   'x-envoy-upstream-service-time': '129',
#   'server': 'envoy',
#   'x-envoy-decorator-operation': 'du-rss.publishing.nyti.nyt.net:443/*',
#   'content-encoding': 'gzip',
#   'accept-ranges': 'bytes',
#   'age': '226',
#   'date': 'Mon, 28 Jul 2025 14:21:32 GMT',
#   'via': '1.1 varnish',
#   'x-served-by': 'cache-ccu830046-CCU',
#   'x-cache': 'HIT',
#   'x-cache-hits': '0',
#   'x-timer': 'S1753712492.335452,VS0,VE1',
#   'vary': 'Accept-Encoding',
#   'strict-transport-security': 'max-age=63072000; preload; includeSubdomains'},
#  'href': 'https://rss.nytimes.com/services/xml/rss/nyt/Technology.xml',
#  'status': 200,
#  'encoding': 'utf-8',
#  'version': 'rss20',
#  'namespaces': {'dc': 'http://purl.org/dc/elements/1.1/',
#   'media': 'http://search.yahoo.com/mrss/',
#   '': 'http://www.w3.org/2005/Atom',
#   'nyt': 'http://www.nytimes.com/namespaces/rss/2.0'}}

# %%
bbc
# Out:
# {'bozo': False,
#  'entries': [{'title': 'EU and US agree trade deal, with 15% tariffs for European exports to America',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://feeds.bbci.co.uk/news/world/rss.xml',
#     'value': 'EU and US agree trade deal, with 15% tariffs for European exports to America'},
#    'summary': 'US President Donald Trump and EU chief Ursula von der Leyen shake on it after "tough negotiations" in Scotland.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://feeds.bbci.co.uk/news/world/rss.xml',
#     'value': 'US President Donald Trump and EU chief Ursula von der Leyen shake on it after "tough negotiations" in Scotland.'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.bbc.com/news/articles/cx2xylk3d07o?at_medium=RSS&at_campaign=rss'}],
#    'link': 'https://www.bbc.com/news/articles/cx2xylk3d07o?at_medium=RSS&at_campaign=rss',
#    'id': 'https://www.bbc.com/news/articles/cx2xylk3d07o#0',
#    'guidislink': False,
#    'published': 'Sun, 27 Jul 2025 23:39:11 GMT',
#    'published_parsed': time.struct_time(tm_year=2025, tm_mon=7, tm_mday=27, tm_hour=23, tm_min=39, tm_sec=11, tm_wday=6, tm_yday=208, tm_isdst=0),
#    'media_thumbnail': [{'width': '240',
#      'height': '135',
#      'url': 'https://ichef.bbci.co.uk/ace/standard/240/cpsprodpb/dbc4/live/625dbf60-6b1d-11f0-8dbd-f3d32ebd3327.jpg'}],
#    'href': ''},
#   {'title': 'Who are the winners and losers in US-EU trade deal?',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://feeds.bbci.co.uk/news/world/rss.xml',
#     'value': 'Who are the winners and losers in US-EU trade deal?'},
#    'summary': 'Carmakers, consumers and European solidarity - a look at who is up and who is down due to the latest tariffs.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://feeds.bbci.co.uk/news/world/rss.xml',
#     'value': 'Carmakers, consumers and European solidarity - a look at who is up and who is down due to the latest tariffs.'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.bbc.com/news/articles/c14g8gk8vdlo?at_medium=RSS&at_campaign=rss'}],
#    'link': 'https://www.bbc.com/news/articles/c14g8gk8vdlo?at_medium=RSS&at_campaign=rss',
#    'id': 'https://www.bbc.com/news/articles/c14g8gk8vdlo#0',
#    'guidislink': False,
#    'published': 'Mon, 28 Jul 2025 10:41:55 GMT',
#    'published_parsed': time.struct_time(tm_year=2025, tm_mon=7, tm_mday=28, tm_hour=10, tm_min=41, tm_sec=55, tm_wday=0, tm_yday=209, tm_isdst=0),
#    'media_thumbnail': [{'width': '240',
#      'height': '135',
#      'url': 'https://ichef.bbci.co.uk/ace/standard/240/cpsprodpb/6362/live/4b85ff10-6b94-11f0-af20-030418be2ca5.jpg'}],
#    'href': ''},
#   {'title': "Thailand and Cambodia agree to 'immediate ceasefire'",
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://feeds.bbci.co.uk/news/world/rss.xml',
#     'value': "Thailand and Cambodia agree to 'immediate ceasefire'"},
#    'summary': 'US President Donald Trump threatened to pause tariff negotiations until the hostilities stopped.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://feeds.bbci.co.uk/news/world/rss.xml',
#     'value': 'US President Donald Trump threatened to pause tariff negotiations until the hostilities stopped.'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.bbc.com/news/articles/c5yl9l60e3no?at_medium=RSS&at_campaign=rss'}],
#    'link': 'https://www.bbc.com/news/articles/c5yl9l60e3no?at_medium=RSS&at_campaign=rss',
#    'id': 'https://www.bbc.com/news/articles/c5yl9l60e3no#0',
#    'guidislink': False,
#    'published': 'Mon, 28 Jul 2025 12:23:19 GMT',
#    'published_parsed': time.struct_time(tm_year=2025, tm_mon=7, tm_mday=28, tm_hour=12, tm_min=23, tm_sec=19, tm_wday=0, tm_yday=209, tm_isdst=0),
#    'media_thumbnail': [{'width': '240',
#      'height': '135',
#      'url': 'https://ichef.bbci.co.uk/ace/standard/240/cpsprodpb/2d5a/live/39d60ab0-6ba5-11f0-89ea-4d6f9851f623.jpg'}],
#    'href': ''},
#   {'title': 'Google failed to warn 10 million of Turkey earthquake severity',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://feeds.bbci.co.uk/news/world/rss.xml',
#     'value': 'Google failed to warn 10 million of Turkey earthquake severity'},
#    'summary': 'The tech giant said only 469 serious warnings were sent out ahead of the 7.8 magnitude quake.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://feeds.bbci.co.uk/news/world/rss.xml',
#     'value': 'The tech giant said only 469 serious warnings were sent out ahead of the 7.8 magnitude quake.'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.bbc.com/news/articles/c77v2kx304go?at_medium=RSS&at_campaign=rss'}],
#    'link': 'https://www.bbc.com/news/articles/c77v2kx304go?at_medium=RSS&at_campaign=rss',
#    'id': 'https://www.bbc.com/news/articles/c77v2kx304go#0',
#    'guidislink': False,
#    'published': 'Sun, 27 Jul 2025 23:16:50 GMT',
#    'published_parsed': time.struct_time(tm_year=2025, tm_mon=7, tm_mday=27, tm_hour=23, tm_min=16, tm_sec=50, tm_wday=6, tm_yday=208, tm_isdst=0),
#    'media_thumbnail': [{'width': '240',
#      'height': '135',
#      'url': 'https://ichef.bbci.co.uk/ace/standard/240/cpsprodpb/b789/live/e55924c0-6b47-11f0-89ea-4d6f9851f623.jpg'}],
#    'href': ''},
#   {'title': 'Five killed in Bangkok market mass shooting',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://feeds.bbci.co.uk/news/world/rss.xml',
#     'value': 'Five killed in Bangkok market mass shooting'},
#    'summary': "Police say officers are investigating the motive behind the incident in Thailand's capital.",
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://feeds.bbci.co.uk/news/world/rss.xml',
#     'value': "Police say officers are investigating the motive behind the incident in Thailand's capital."},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.bbc.com/news/articles/c9qyvx771neo?at_medium=RSS&at_campaign=rss'}],
#    'link': 'https://www.bbc.com/news/articles/c9qyvx771neo?at_medium=RSS&at_campaign=rss',
#    'id': 'https://www.bbc.com/news/articles/c9qyvx771neo#0',
#    'guidislink': False,
#    'published': 'Mon, 28 Jul 2025 08:19:12 GMT',
#    'published_parsed': time.struct_time(tm_year=2025, tm_mon=7, tm_mday=28, tm_hour=8, tm_min=19, tm_sec=12, tm_wday=0, tm_yday=209, tm_isdst=0),
#    'media_thumbnail': [{'width': '240',
#      'height': '135',
#      'url': 'https://ichef.bbci.co.uk/ace/standard/240/cpsprodpb/1c0a/live/93699270-6b84-11f0-97ab-a907c677cb2a.jpg'}],
#    'href': ''},
#   {'title': 'Southern European heatwave fans multiple wildfires',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://feeds.bbci.co.uk/news/world/rss.xml',
#     'value': 'Southern European heatwave fans multiple wildfires'},
#    'summary': 'Greece and Turkey are among the countries battling wildfires as temperatures spike in southern Europe.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://feeds.bbci.co.uk/news/world/rss.xml',
#     'value': 'Greece and Turkey are among the countries battling wildfires as temperatures spike in southern Europe.'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.bbc.com/news/videos/c23pk70mz13o?at_medium=RSS&at_campaign=rss'}],
#    'link': 'https://www.bbc.com/news/videos/c23pk70mz13o?at_medium=RSS&at_campaign=rss',
#    'id': 'https://www.bbc.com/news/videos/c23pk70mz13o#1',
#    'guidislink': False,
#    'published': 'Mon, 28 Jul 2025 10:57:11 GMT',
#    'published_parsed': time.struct_time(tm_year=2025, tm_mon=7, tm_mday=28, tm_hour=10, tm_min=57, tm_sec=11, tm_wday=0, tm_yday=209, tm_isdst=0),
#    'media_thumbnail': [{'width': '240',
#      'height': '134',
#      'url': 'https://ichef.bbci.co.uk/ace/standard/240/cpsprodpb/012a/live/337345d0-6b9f-11f0-89ea-4d6f9851f623.jpg'}],
#    'href': ''},
#   {'title': 'American musical satirist Tom Lehrer dies at 97, US media report',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://feeds.bbci.co.uk/news/world/rss.xml',
#     'value': 'American musical satirist Tom Lehrer dies at 97, US media report'},
#    'summary': 'Lehrer, a Harvard-trained mathematician, wrote darkly humorous songs, often with political connotations.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://feeds.bbci.co.uk/news/world/rss.xml',
#     'value': 'Lehrer, a Harvard-trained mathematician, wrote darkly humorous songs, often with political connotations.'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.bbc.com/news/articles/cpv02yd2714o?at_medium=RSS&at_campaign=rss'}],
#    'link': 'https://www.bbc.com/news/articles/cpv02yd2714o?at_medium=RSS&at_campaign=rss',
#    'id': 'https://www.bbc.com/news/articles/cpv02yd2714o#1',
#    'guidislink': False,
#    'published': 'Sun, 27 Jul 2025 22:21:38 GMT',
#    'published_parsed': time.struct_time(tm_year=2025, tm_mon=7, tm_mday=27, tm_hour=22, tm_min=21, tm_sec=38, tm_wday=6, tm_yday=208, tm_isdst=0),
#    'media_thumbnail': [{'width': '240',
#      'height': '135',
#      'url': 'https://ichef.bbci.co.uk/ace/standard/240/cpsprodpb/edcb/live/2a516690-6b0d-11f0-89ea-4d6f9851f623.jpg'}],
#    'href': ''},
#   {'title': 'Suspect faces terrorism charges in stabbing of 11 at Walmart in Michigan',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://feeds.bbci.co.uk/news/world/rss.xml',
#     'value': 'Suspect faces terrorism charges in stabbing of 11 at Walmart in Michigan'},
#    'summary': "Investigators are yet to reveal a motive for Saturday afternoon's attack in Traverse City.",
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://feeds.bbci.co.uk/news/world/rss.xml',
#     'value': "Investigators are yet to reveal a motive for Saturday afternoon's attack in Traverse City."},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.bbc.com/news/articles/ckgjmr9y7x2o?at_medium=RSS&at_campaign=rss'}],
#    'link': 'https://www.bbc.com/news/articles/ckgjmr9y7x2o?at_medium=RSS&at_campaign=rss',
#    'id': 'https://www.bbc.com/news/articles/ckgjmr9y7x2o#1',
#    'guidislink': False,
#    'published': 'Sun, 27 Jul 2025 22:10:11 GMT',
#    'published_parsed': time.struct_time(tm_year=2025, tm_mon=7, tm_mday=27, tm_hour=22, tm_min=10, tm_sec=11, tm_wday=6, tm_yday=208, tm_isdst=0),
#    'media_thumbnail': [{'width': '240',
#      'height': '135',
#      'url': 'https://ichef.bbci.co.uk/ace/standard/240/cpsprodpb/aa95/live/f6f571b0-6a94-11f0-8dbd-f3d32ebd3327.jpg'}],
#    'href': ''},
#   {'title': 'Sewage spill caused deadly train derailment in Germany, police say',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://feeds.bbci.co.uk/news/world/rss.xml',
#     'value': 'Sewage spill caused deadly train derailment in Germany, police say'},
#    'summary': 'The train driver, another rail employee and one passenger died, while 41 people were injured, prosecutors say.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://feeds.bbci.co.uk/news/world/rss.xml',
#     'value': 'The train driver, another rail employee and one passenger died, while 41 people were injured, prosecutors say.'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.bbc.com/news/articles/cy9844egpx8o?at_medium=RSS&at_campaign=rss'}],
#    'link': 'https://www.bbc.com/news/articles/cy9844egpx8o?at_medium=RSS&at_campaign=rss',
#    'id': 'https://www.bbc.com/news/articles/cy9844egpx8o#1',
#    'guidislink': False,
#    'published': 'Mon, 28 Jul 2025 07:58:14 GMT',
#    'published_parsed': time.struct_time(tm_year=2025, tm_mon=7, tm_mday=28, tm_hour=7, tm_min=58, tm_sec=14, tm_wday=0, tm_yday=209, tm_isdst=0),
#    'media_thumbnail': [{'width': '240',
#      'height': '135',
#      'url': 'https://ichef.bbci.co.uk/ace/standard/240/cpsprodpb/4497/live/946a0f20-6b5b-11f0-af20-030418be2ca5.jpg'}],
#    'href': ''},
#   {'title': 'More than 40 killed in DR Congo attack linked to Islamic State',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://feeds.bbci.co.uk/news/world/rss.xml',
#     'value': 'More than 40 killed in DR Congo attack linked to Islamic State'},
#    'summary': 'Most of the dead were worshippers taking part in a night vigil which was stormed by armed men, officials said.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://feeds.bbci.co.uk/news/world/rss.xml',
#     'value': 'Most of the dead were worshippers taking part in a night vigil which was stormed by armed men, officials said.'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.bbc.com/news/articles/c3ezjg34lw4o?at_medium=RSS&at_campaign=rss'}],
#    'link': 'https://www.bbc.com/news/articles/c3ezjg34lw4o?at_medium=RSS&at_campaign=rss',
#    'id': 'https://www.bbc.com/news/articles/c3ezjg34lw4o#1',
#    'guidislink': False,
#    'published': 'Mon, 28 Jul 2025 08:05:16 GMT',
#    'published_parsed': time.struct_time(tm_year=2025, tm_mon=7, tm_mday=28, tm_hour=8, tm_min=5, tm_sec=16, tm_wday=0, tm_yday=209, tm_isdst=0),
#    'media_thumbnail': [{'width': '240',
#      'height': '135',
#      'url': 'https://ichef.bbci.co.uk/ace/standard/240/cpsprodpb/ed12/live/92122290-6af1-11f0-aab0-6dfa4f4c8e30.jpg'}],
#    'href': ''},
#   {'title': "Astronomer's 'clever' PR move embracing CEO scandal - featuring Gwyneth Paltrow",
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://feeds.bbci.co.uk/news/world/rss.xml',
#     'value': "Astronomer's 'clever' PR move embracing CEO scandal - featuring Gwyneth Paltrow"},
#    'summary': "The company at the heart of the Coldplay 'kiss cam' scandal has released a video featuring the ex-wife of Chris Martin.",
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://feeds.bbci.co.uk/news/world/rss.xml',
#     'value': "The company at the heart of the Coldplay 'kiss cam' scandal has released a video featuring the ex-wife of Chris Martin."},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.bbc.com/news/articles/crlzrjp2e2lo?at_medium=RSS&at_campaign=rss'}],
#    'link': 'https://www.bbc.com/news/articles/crlzrjp2e2lo?at_medium=RSS&at_campaign=rss',
#    'id': 'https://www.bbc.com/news/articles/crlzrjp2e2lo#1',
#    'guidislink': False,
#    'published': 'Sun, 27 Jul 2025 08:24:15 GMT',
#    'published_parsed': time.struct_time(tm_year=2025, tm_mon=7, tm_mday=27, tm_hour=8, tm_min=24, tm_sec=15, tm_wday=6, tm_yday=208, tm_isdst=0),
#    'media_thumbnail': [{'width': '240',
#      'height': '135',
#      'url': 'https://ichef.bbci.co.uk/ace/standard/240/cpsprodpb/6d23/live/b6dfd050-6ac8-11f0-8dbd-f3d32ebd3327.jpg'}],
#    'href': ''},
#   {'title': "Bowen: Israel's aid measures a gesture to allies horrified by Gaza starvation",
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://feeds.bbci.co.uk/news/world/rss.xml',
#     'value': "Bowen: Israel's aid measures a gesture to allies horrified by Gaza starvation"},
#    'summary': 'This might be a tacit admission by the Israelis that they need to do more - but more likely the measures are a response to allies.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://feeds.bbci.co.uk/news/world/rss.xml',
#     'value': 'This might be a tacit admission by the Israelis that they need to do more - but more likely the measures are a response to allies.'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.bbc.com/news/articles/cz60x5v75p1o?at_medium=RSS&at_campaign=rss'}],
#    'link': 'https://www.bbc.com/news/articles/cz60x5v75p1o?at_medium=RSS&at_campaign=rss',
#    'id': 'https://www.bbc.com/news/articles/cz60x5v75p1o#2',
#    'guidislink': False,
#    'published': 'Sun, 27 Jul 2025 15:01:21 GMT',
#    'published_parsed': time.struct_time(tm_year=2025, tm_mon=7, tm_mday=27, tm_hour=15, tm_min=1, tm_sec=21, tm_wday=6, tm_yday=208, tm_isdst=0),
#    'media_thumbnail': [{'width': '240',
#      'height': '135',
#      'url': 'https://ichef.bbci.co.uk/ace/standard/240/cpsprodpb/38ce/live/5126a750-6ae8-11f0-8dbd-f3d32ebd3327.jpg'}],
#    'href': ''},
#   {'title': 'BBC uncovers lasting toxic legacy of cargo ship disaster off Sri Lanka',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://feeds.bbci.co.uk/news/world/rss.xml',
#     'value': 'BBC uncovers lasting toxic legacy of cargo ship disaster off Sri Lanka'},
#    'summary': 'Scientists warn the damage to the environment after the 2021 X-Press Pearl disaster could be much more enduring.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://feeds.bbci.co.uk/news/world/rss.xml',
#     'value': 'Scientists warn the damage to the environment after the 2021 X-Press Pearl disaster could be much more enduring.'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.bbc.com/news/articles/cly8y5kmrllo?at_medium=RSS&at_campaign=rss'}],
#    'link': 'https://www.bbc.com/news/articles/cly8y5kmrllo?at_medium=RSS&at_campaign=rss',
#    'id': 'https://www.bbc.com/news/articles/cly8y5kmrllo#2',
#    'guidislink': False,
#    'published': 'Sun, 27 Jul 2025 22:15:24 GMT',
#    'published_parsed': time.struct_time(tm_year=2025, tm_mon=7, tm_mday=27, tm_hour=22, tm_min=15, tm_sec=24, tm_wday=6, tm_yday=208, tm_isdst=0),
#    'media_thumbnail': [{'width': '240',
#      'height': '135',
#      'url': 'https://ichef.bbci.co.uk/ace/standard/240/cpsprodpb/7621/live/35a47490-68a8-11f0-a9fb-7f350e3f05ac.jpg'}],
#    'href': ''},
#   {'title': "How Trump wants the US to cash in on mineral-rich DR Congo's peace deal",
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://feeds.bbci.co.uk/news/world/rss.xml',
#     'value': "How Trump wants the US to cash in on mineral-rich DR Congo's peace deal"},
#    'summary': 'The US president is spearheading an ambitious but controversial deal to end a long-running conflict.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://feeds.bbci.co.uk/news/world/rss.xml',
#     'value': 'The US president is spearheading an ambitious but controversial deal to end a long-running conflict.'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.bbc.com/news/articles/cew0vzl7rwjo?at_medium=RSS&at_campaign=rss'}],
#    'link': 'https://www.bbc.com/news/articles/cew0vzl7rwjo?at_medium=RSS&at_campaign=rss',
#    'id': 'https://www.bbc.com/news/articles/cew0vzl7rwjo#2',
#    'guidislink': False,
#    'published': 'Sun, 27 Jul 2025 23:59:52 GMT',
#    'published_parsed': time.struct_time(tm_year=2025, tm_mon=7, tm_mday=27, tm_hour=23, tm_min=59, tm_sec=52, tm_wday=6, tm_yday=208, tm_isdst=0),
#    'media_thumbnail': [{'width': '240',
#      'height': '135',
#      'url': 'https://ichef.bbci.co.uk/ace/standard/240/cpsprodpb/af90/live/9ffb6dd0-6876-11f0-af20-030418be2ca5.jpg'}],
#    'href': ''},
#   {'title': "Ancient site stirs heated political debate on India's past",
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://feeds.bbci.co.uk/news/world/rss.xml',
#     'value': "Ancient site stirs heated political debate on India's past"},
#    'summary': 'The archaeological site of Keeladi has unearthed remnants of an urban settlement, fuelling competing historical claims.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://feeds.bbci.co.uk/news/world/rss.xml',
#     'value': 'The archaeological site of Keeladi has unearthed remnants of an urban settlement, fuelling competing historical claims.'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.bbc.com/news/articles/cwyq443xypjo?at_medium=RSS&at_campaign=rss'}],
#    'link': 'https://www.bbc.com/news/articles/cwyq443xypjo?at_medium=RSS&at_campaign=rss',
#    'id': 'https://www.bbc.com/news/articles/cwyq443xypjo#2',
#    'guidislink': False,
#    'published': 'Sun, 27 Jul 2025 23:01:48 GMT',
#    'published_parsed': time.struct_time(tm_year=2025, tm_mon=7, tm_mday=27, tm_hour=23, tm_min=1, tm_sec=48, tm_wday=6, tm_yday=208, tm_isdst=0),
#    'media_thumbnail': [{'width': '240',
#      'height': '134',
#      'url': 'https://ichef.bbci.co.uk/ace/standard/240/cpsprodpb/1392/live/8ed6e6e0-6792-11f0-89ea-4d6f9851f623.jpg'}],
#    'href': ''},
#   {'title': 'The Caribbean islands that give you a passport if you buy a home',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://feeds.bbci.co.uk/news/world/rss.xml',
#     'value': 'The Caribbean islands that give you a passport if you buy a home'},
#    'summary': "Five of the region's island nations offer such citizenship by investment for as little as $200,000.",
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://feeds.bbci.co.uk/news/world/rss.xml',
#     'value': "Five of the region's island nations offer such citizenship by investment for as little as $200,000."},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.bbc.com/news/articles/cly88xg5d9vo?at_medium=RSS&at_campaign=rss'}],
#    'link': 'https://www.bbc.com/news/articles/cly88xg5d9vo?at_medium=RSS&at_campaign=rss',
#    'id': 'https://www.bbc.com/news/articles/cly88xg5d9vo#2',
#    'guidislink': False,
#    'published': 'Sun, 27 Jul 2025 23:46:06 GMT',
#    'published_parsed': time.struct_time(tm_year=2025, tm_mon=7, tm_mday=27, tm_hour=23, tm_min=46, tm_sec=6, tm_wday=6, tm_yday=208, tm_isdst=0),
#    'media_thumbnail': [{'width': '240',
#      'height': '135',
#      'url': 'https://ichef.bbci.co.uk/ace/standard/240/cpsprodpb/612f/live/299a1cd0-567a-11f0-95fc-edf89039c20a.jpg'}],
#    'href': ''},
#   {'title': "The last custodian: A Kashmiri artisan's battle to save a musical legacy",
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://feeds.bbci.co.uk/news/world/rss.xml',
#     'value': "The last custodian: A Kashmiri artisan's battle to save a musical legacy"},
#    'summary': 'Ghulam Mohammed Zaz fears for the future of the hand-made santoor as there are no takers for the dying artform.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://feeds.bbci.co.uk/news/world/rss.xml',
#     'value': 'Ghulam Mohammed Zaz fears for the future of the hand-made santoor as there are no takers for the dying artform.'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.bbc.com/news/articles/cp34x44g2xwo?at_medium=RSS&at_campaign=rss'}],
#    'link': 'https://www.bbc.com/news/articles/cp34x44g2xwo?at_medium=RSS&at_campaign=rss',
#    'id': 'https://www.bbc.com/news/articles/cp34x44g2xwo#2',
#    'guidislink': False,
#    'published': 'Sun, 27 Jul 2025 01:04:33 GMT',
#    'published_parsed': time.struct_time(tm_year=2025, tm_mon=7, tm_mday=27, tm_hour=1, tm_min=4, tm_sec=33, tm_wday=6, tm_yday=208, tm_isdst=0),
#    'media_thumbnail': [{'width': '240',
#      'height': '134',
#      'url': 'https://ichef.bbci.co.uk/ace/standard/240/cpsprodpb/9305/live/23dec680-6230-11f0-8bb8-6da7e50368a3.jpg'}],
#    'href': ''},
#   {'title': 'Europe accused of going soft on Azerbaijan to avoid buying Russian gas',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://feeds.bbci.co.uk/news/world/rss.xml',
#     'value': 'Europe accused of going soft on Azerbaijan to avoid buying Russian gas'},
#    'summary': "Critics say EU policy has given Azerbaijan's President Ilham Aliyev a free hand during his crackdown on opponents.",
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://feeds.bbci.co.uk/news/world/rss.xml',
#     'value': "Critics say EU policy has given Azerbaijan's President Ilham Aliyev a free hand during his crackdown on opponents."},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.bbc.com/news/articles/c5y7yl59nzro?at_medium=RSS&at_campaign=rss'}],
#    'link': 'https://www.bbc.com/news/articles/c5y7yl59nzro?at_medium=RSS&at_campaign=rss',
#    'id': 'https://www.bbc.com/news/articles/c5y7yl59nzro#2',
#    'guidislink': False,
#    'published': 'Sat, 26 Jul 2025 23:19:02 GMT',
#    'published_parsed': time.struct_time(tm_year=2025, tm_mon=7, tm_mday=26, tm_hour=23, tm_min=19, tm_sec=2, tm_wday=5, tm_yday=207, tm_isdst=0),
#    'media_thumbnail': [{'width': '240',
#      'height': '134',
#      'url': 'https://ichef.bbci.co.uk/ace/standard/240/cpsprodpb/6c2a/live/dad522f0-6940-11f0-a92d-1fc9e441053b.jpg'}],
#    'href': ''},
#   {'title': "World's thirst for matcha dries up global supplies",
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://feeds.bbci.co.uk/news/world/rss.xml',
#     'value': "World's thirst for matcha dries up global supplies"},
#    'summary': 'Surging demand, smaller tea crops due to heatwaves and US tariffs on Japan are pushing up matcha prices.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://feeds.bbci.co.uk/news/world/rss.xml',
#     'value': 'Surging demand, smaller tea crops due to heatwaves and US tariffs on Japan are pushing up matcha prices.'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.bbc.com/news/articles/cgq7w1n00xeo?at_medium=RSS&at_campaign=rss'}],
#    'link': 'https://www.bbc.com/news/articles/cgq7w1n00xeo?at_medium=RSS&at_campaign=rss',
#    'id': 'https://www.bbc.com/news/articles/cgq7w1n00xeo#2',
#    'guidislink': False,
#    'published': 'Fri, 25 Jul 2025 22:41:15 GMT',
#    'published_parsed': time.struct_time(tm_year=2025, tm_mon=7, tm_mday=25, tm_hour=22, tm_min=41, tm_sec=15, tm_wday=4, tm_yday=206, tm_isdst=0),
#    'media_thumbnail': [{'width': '240',
#      'height': '135',
#      'url': 'https://ichef.bbci.co.uk/ace/standard/240/cpsprodpb/3935/live/0b1bf140-65d7-11f0-90b5-7f02d0e68902.jpg'}],
#    'href': ''},
#   {'title': "School-leavers losing their lives for Russia in Putin's war with Ukraine",
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://feeds.bbci.co.uk/news/world/rss.xml',
#     'value': "School-leavers losing their lives for Russia in Putin's war with Ukraine"},
#    'summary': 'Russia has promised that no 18-year-olds will be sent to fight in Ukraine, but the BBC finds many have already been killed.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://feeds.bbci.co.uk/news/world/rss.xml',
#     'value': 'Russia has promised that no 18-year-olds will be sent to fight in Ukraine, but the BBC finds many have already been killed.'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.bbc.com/news/articles/ce9xkg7dmd5o?at_medium=RSS&at_campaign=rss'}],
#    'link': 'https://www.bbc.com/news/articles/ce9xkg7dmd5o?at_medium=RSS&at_campaign=rss',
#    'id': 'https://www.bbc.com/news/articles/ce9xkg7dmd5o#2',
#    'guidislink': False,
#    'published': 'Sat, 26 Jul 2025 00:54:03 GMT',
#    'published_parsed': time.struct_time(tm_year=2025, tm_mon=7, tm_mday=26, tm_hour=0, tm_min=54, tm_sec=3, tm_wday=5, tm_yday=207, tm_isdst=0),
#    'media_thumbnail': [{'width': '240',
#      'height': '134',
#      'url': 'https://ichef.bbci.co.uk/ace/standard/240/cpsprodpb/fafb/live/c3829370-67ed-11f0-a665-63ea82eef55b.jpg'}],
#    'href': ''},
#   {'title': 'Tee time with Trump - striking balls and deals over 18 holes',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://feeds.bbci.co.uk/news/world/rss.xml',
#     'value': 'Tee time with Trump - striking balls and deals over 18 holes'},
#    'summary': 'For some US presidents, golf was a break from work - but for Trump, visiting Scotland this weekend, it is anything but.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://feeds.bbci.co.uk/news/world/rss.xml',
#     'value': 'For some US presidents, golf was a break from work - but for Trump, visiting Scotland this weekend, it is anything but.'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.bbc.com/news/articles/cly2y4w47deo?at_medium=RSS&at_campaign=rss'}],
#    'link': 'https://www.bbc.com/news/articles/cly2y4w47deo?at_medium=RSS&at_campaign=rss',
#    'id': 'https://www.bbc.com/news/articles/cly2y4w47deo#2',
#    'guidislink': False,
#    'published': 'Sat, 26 Jul 2025 00:33:54 GMT',
#    'published_parsed': time.struct_time(tm_year=2025, tm_mon=7, tm_mday=26, tm_hour=0, tm_min=33, tm_sec=54, tm_wday=5, tm_yday=207, tm_isdst=0),
#    'media_thumbnail': [{'width': '240',
#      'height': '135',
#      'url': 'https://ichef.bbci.co.uk/ace/standard/240/cpsprodpb/574f/live/46253380-6962-11f0-89ea-4d6f9851f623.jpg'}],
#    'href': ''},
#   {'title': '\u200b\u200bWhat is inside the GHF food aid box being distributed in Gaza?',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://feeds.bbci.co.uk/news/world/rss.xml',
#     'value': '\u200b\u200bWhat is inside the GHF food aid box being distributed in Gaza?'},
#    'summary': 'BBC Verify examines the meals handed out to Gazans - and why their nutritional value is questioned by some experts.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://feeds.bbci.co.uk/news/world/rss.xml',
#     'value': 'BBC Verify examines the meals handed out to Gazans - and why their nutritional value is questioned by some experts.'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.bbc.com/news/articles/cd787er1qz4o?at_medium=RSS&at_campaign=rss'}],
#    'link': 'https://www.bbc.com/news/articles/cd787er1qz4o?at_medium=RSS&at_campaign=rss',
#    'id': 'https://www.bbc.com/news/articles/cd787er1qz4o#2',
#    'guidislink': False,
#    'published': 'Fri, 25 Jul 2025 23:41:52 GMT',
#    'published_parsed': time.struct_time(tm_year=2025, tm_mon=7, tm_mday=25, tm_hour=23, tm_min=41, tm_sec=52, tm_wday=4, tm_yday=206, tm_isdst=0),
#    'media_thumbnail': [{'width': '240',
#      'height': '135',
#      'url': 'https://ichef.bbci.co.uk/ace/standard/240/cpsprodpb/7108/live/76572300-68a5-11f0-89ea-4d6f9851f623.jpg'}],
#    'href': ''},
#   {'title': 'Thais and Cambodians slug it out on social media, as border tensions flare',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://feeds.bbci.co.uk/news/world/rss.xml',
#     'value': 'Thais and Cambodians slug it out on social media, as border tensions flare'},
#    'summary': 'A war of words is raging on social media, a years-long battleground for Thais and Cambodians.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://feeds.bbci.co.uk/news/world/rss.xml',
#     'value': 'A war of words is raging on social media, a years-long battleground for Thais and Cambodians.'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.bbc.com/news/articles/cy9x91ewzvxo?at_medium=RSS&at_campaign=rss'}],
#    'link': 'https://www.bbc.com/news/articles/cy9x91ewzvxo?at_medium=RSS&at_campaign=rss',
#    'id': 'https://www.bbc.com/news/articles/cy9x91ewzvxo#2',
#    'guidislink': False,
#    'published': 'Sat, 26 Jul 2025 00:43:53 GMT',
#    'published_parsed': time.struct_time(tm_year=2025, tm_mon=7, tm_mday=26, tm_hour=0, tm_min=43, tm_sec=53, tm_wday=5, tm_yday=207, tm_isdst=0),
#    'media_thumbnail': [{'width': '240',
#      'height': '135',
#      'url': 'https://ichef.bbci.co.uk/ace/standard/240/cpsprodpb/47c0/live/bb759c10-69cb-11f0-89ea-4d6f9851f623.jpg'}],
#    'href': ''},
#   {'title': 'Southern European heatwave fans multiple wildfires',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://feeds.bbci.co.uk/news/world/rss.xml',
#     'value': 'Southern European heatwave fans multiple wildfires'},
#    'summary': 'Greece and Turkey are among the countries battling wildfires as temperatures spike in southern Europe.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://feeds.bbci.co.uk/news/world/rss.xml',
#     'value': 'Greece and Turkey are among the countries battling wildfires as temperatures spike in southern Europe.'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.bbc.com/news/videos/c23pk70mz13o?at_medium=RSS&at_campaign=rss'}],
#    'link': 'https://www.bbc.com/news/videos/c23pk70mz13o?at_medium=RSS&at_campaign=rss',
#    'id': 'https://www.bbc.com/news/videos/c23pk70mz13o#3',
#    'guidislink': False,
#    'published': 'Mon, 28 Jul 2025 10:57:11 GMT',
#    'published_parsed': time.struct_time(tm_year=2025, tm_mon=7, tm_mday=28, tm_hour=10, tm_min=57, tm_sec=11, tm_wday=0, tm_yday=209, tm_isdst=0),
#    'media_thumbnail': [{'width': '240',
#      'height': '134',
#      'url': 'https://ichef.bbci.co.uk/ace/standard/240/cpsprodpb/012a/live/337345d0-6b9f-11f0-89ea-4d6f9851f623.jpg'}],
#    'href': ''},
#   {'title': 'Passengers use emergency slides to flee plane fire in US',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://feeds.bbci.co.uk/news/world/rss.xml',
#     'value': 'Passengers use emergency slides to flee plane fire in US'},
#    'summary': 'One person was taken to hospital after a fire started during takeoff.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://feeds.bbci.co.uk/news/world/rss.xml',
#     'value': 'One person was taken to hospital after a fire started during takeoff.'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.bbc.com/news/videos/cpwy8p72zr9o?at_medium=RSS&at_campaign=rss'}],
#    'link': 'https://www.bbc.com/news/videos/cpwy8p72zr9o?at_medium=RSS&at_campaign=rss',
#    'id': 'https://www.bbc.com/news/videos/cpwy8p72zr9o#3',
#    'guidislink': False,
#    'published': 'Sun, 27 Jul 2025 04:40:04 GMT',
#    'published_parsed': time.struct_time(tm_year=2025, tm_mon=7, tm_mday=27, tm_hour=4, tm_min=40, tm_sec=4, tm_wday=6, tm_yday=208, tm_isdst=0),
#    'media_thumbnail': [{'width': '240',
#      'height': '135',
#      'url': 'https://ichef.bbci.co.uk/ace/standard/240/cpsprodpb/5d3d/live/3412e310-6aa0-11f0-8dbd-f3d32ebd3327.jpg'}],
#    'href': ''},
#   {'title': "'I witnessed war crimes' in Gaza, former worker at GHF aid site tells BBC",
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://feeds.bbci.co.uk/news/world/rss.xml',
#     'value': "'I witnessed war crimes' in Gaza, former worker at GHF aid site tells BBC"},
#    'summary': 'A retired US soldier reveals why he quit working at Israel and US-backed Gaza Humanitarian Foundation aid hubs.',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://feeds.bbci.co.uk/news/world/rss.xml',
#     'value': 'A retired US soldier reveals why he quit working at Israel and US-backed Gaza Humanitarian Foundation aid hubs.'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.bbc.com/news/videos/cy8k8045nx9o?at_medium=RSS&at_campaign=rss'}],
#    'link': 'https://www.bbc.com/news/videos/cy8k8045nx9o?at_medium=RSS&at_campaign=rss',
#    'id': 'https://www.bbc.com/news/videos/cy8k8045nx9o#3',
#    'guidislink': False,
#    'published': 'Fri, 25 Jul 2025 22:10:39 GMT',
#    'published_parsed': time.struct_time(tm_year=2025, tm_mon=7, tm_mday=25, tm_hour=22, tm_min=10, tm_sec=39, tm_wday=4, tm_yday=206, tm_isdst=0),
#    'media_thumbnail': [{'width': '240',
#      'height': '135',
#      'url': 'https://ichef.bbci.co.uk/ace/standard/240/cpsprodpb/f756/live/cfff6660-69a4-11f0-8dbd-f3d32ebd3327.jpg'}],
#    'href': ''},
#   {'title': "'I'm so tired': Mother of starving Gazan baby speaks to BBC",
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://feeds.bbci.co.uk/news/world/rss.xml',
#     'value': "'I'm so tired': Mother of starving Gazan baby speaks to BBC"},
#    'summary': "Hedaya al-Muta'wi's 18-month-old son Mohammed suffers from malnutrition due to famine, weighing just 6kg.",
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://feeds.bbci.co.uk/news/world/rss.xml',
#     'value': "Hedaya al-Muta'wi's 18-month-old son Mohammed suffers from malnutrition due to famine, weighing just 6kg."},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.bbc.com/news/videos/c4gdg13rrx4o?at_medium=RSS&at_campaign=rss'}],
#    'link': 'https://www.bbc.com/news/videos/c4gdg13rrx4o?at_medium=RSS&at_campaign=rss',
#    'id': 'https://www.bbc.com/news/videos/c4gdg13rrx4o#3',
#    'guidislink': False,
#    'published': 'Fri, 25 Jul 2025 18:21:29 GMT',
#    'published_parsed': time.struct_time(tm_year=2025, tm_mon=7, tm_mday=25, tm_hour=18, tm_min=21, tm_sec=29, tm_wday=4, tm_yday=206, tm_isdst=0),
#    'media_thumbnail': [{'width': '240',
#      'height': '135',
#      'url': 'https://ichef.bbci.co.uk/ace/standard/240/cpsprodpb/09ab/live/bfb0c270-6983-11f0-89ea-4d6f9851f623.jpg'}],
#    'href': ''},
#   {'title': "'All the people are hungry': Voices from Gaza on desperate lack of food",
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://feeds.bbci.co.uk/news/world/rss.xml',
#     'value': "'All the people are hungry': Voices from Gaza on desperate lack of food"},
#    'summary': "All week across the BBC we've been hearing from people in Gaza about their lives as food supplies are restricted leading to malnourishment and starvation.",
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': 'https://feeds.bbci.co.uk/news/world/rss.xml',
#     'value': "All week across the BBC we've been hearing from people in Gaza about their lives as food supplies are restricted leading to malnourishment and starvation."},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.bbc.com/news/videos/c4g8gy52dwgo?at_medium=RSS&at_campaign=rss'}],
#    'link': 'https://www.bbc.com/news/videos/c4g8gy52dwgo?at_medium=RSS&at_campaign=rss',
#    'id': 'https://www.bbc.com/news/videos/c4g8gy52dwgo#3',
#    'guidislink': False,
#    'published': 'Fri, 25 Jul 2025 14:03:55 GMT',
#    'published_parsed': time.struct_time(tm_year=2025, tm_mon=7, tm_mday=25, tm_hour=14, tm_min=3, tm_sec=55, tm_wday=4, tm_yday=206, tm_isdst=0),
#    'media_thumbnail': [{'width': '240',
#      'height': '134',
#      'url': 'https://ichef.bbci.co.uk/ace/standard/240/cpsprodpb/56c2/live/62a2f5c0-695c-11f0-af20-030418be2ca5.jpg'}],
#    'href': ''}],
#  'feed': {'title': 'BBC News',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'https://feeds.bbci.co.uk/news/world/rss.xml',
#    'value': 'BBC News'},
#   'subtitle': 'BBC News - World',
#   'subtitle_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'https://feeds.bbci.co.uk/news/world/rss.xml',
#    'value': 'BBC News - World'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'https://www.bbc.co.uk/news/world'},
#    {'href': 'https://feeds.bbci.co.uk/news/world/rss.xml',
#     'rel': 'self',
#     'type': 'application/rss+xml'}],
#   'link': 'https://www.bbc.co.uk/news/world',
#   'image': {'href': 'https://news.bbcimg.co.uk/nol/shared/img/bbc_news_120x60.gif',
#    'title': 'BBC News',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': 'https://feeds.bbci.co.uk/news/world/rss.xml',
#     'value': 'BBC News'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://www.bbc.co.uk/news/world'}],
#    'link': 'https://www.bbc.co.uk/news/world'},
#   'generator_detail': {'name': 'RSS for Node'},
#   'generator': 'RSS for Node',
#   'updated': 'Mon, 28 Jul 2025 14:21:29 GMT',
#   'updated_parsed': time.struct_time(tm_year=2025, tm_mon=7, tm_mday=28, tm_hour=14, tm_min=21, tm_sec=29, tm_wday=0, tm_yday=209, tm_isdst=0),
#   'rights': 'Copyright: (C) British Broadcasting Corporation, see https://www.bbc.co.uk/usingthebbc/terms-of-use/#15metadataandrssfeeds for terms and conditions of reuse.',
#   'rights_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'https://feeds.bbci.co.uk/news/world/rss.xml',
#    'value': 'Copyright: (C) British Broadcasting Corporation, see https://www.bbc.co.uk/usingthebbc/terms-of-use/#15metadataandrssfeeds for terms and conditions of reuse.'},
#   'language': 'en-gb',
#   'ttl': '15'},
#  'headers': {'server': 'Belfrage',
#   'x-local-cache': 'EXPIRED',
#   'belfrage-cache-status': 'HIT',
#   'bsig': '444e171c4e67d2e37e8b72421793da0d',
#   'content-type': 'text/xml; charset=utf-8',
#   'content-encoding': 'gzip',
#   'brequestid': '8779204ef5464464bf91f4ccd70442d0',
#   'bid': 'cedric',
#   'req-svc-chain': 'BELFRAGE',
#   'x-shared-cache': 'HIT',
#   'content-length': '4845',
#   'cache-control': 'public, max-age=5',
#   'expires': 'Mon, 28 Jul 2025 14:21:37 GMT',
#   'date': 'Mon, 28 Jul 2025 14:21:32 GMT',
#   'connection': 'close',
#   'vary': 'Accept-Encoding',
#   'timing-allow-origin': 'https://www.bbc.co.uk, https://www.bbc.com'},
#  'href': 'https://feeds.bbci.co.uk/news/world/rss.xml',
#  'status': 200,
#  'encoding': 'utf-8',
#  'version': 'rss20',
#  'namespaces': {'dc': 'http://purl.org/dc/elements/1.1/',
#   'content': 'http://purl.org/rss/1.0/modules/content/',
#   '': 'http://www.w3.org/2005/Atom',
#   'media': 'http://search.yahoo.com/mrss/'}}

# %%
vocab_list, p0V, p1V =localwords(nyt,bbc,30)
# Out:
# The error rate is 0.4444444444444444

# %%
vocab_list, p0V, p1V = localwords(nyt,bbc,50)
# Out:
# The error rate is 0.21428571428571427

# %%
vocab_list, p0V, p1V = localwords(nyt,bbc,100)
# Out:
# The error rate is 0.4666666666666667

# %%
getTopWords(nyt,bbc,10)
# Out:
# The error rate is 0.4
# ----------- FEED 1 -----------
# say
# were
# countries
# most
# prosecutors
# smaller
# claims
# greece
# darkly
# armed
# often
# harvard
# matcha
# citizenship
# people
# injured
# martin
# police
# wife
# worshippers
# critics
# hand
# mathematician
# free
# died
# tariff
# his
# stopped
# coldplay
# investment
# opponents
# tea
# heart
# songs
# prices
# officers
# spike
# demand
# heatwaves
# settlement
# officials
# ilham
# offer
# thailand
# little
# island
# such
# surging
# pause
# during
# chris
# remnants
# urban
# kiss
# which
# threatened
# video
# negotiations
# capital
# employee
# released
# political
# motive
# connotations
# nations
# was
# azerbaijan
# region
# wildfires
# while
# unearthed
# archaeological
# humorous
# aliyev
# cam
# battling
# train
# among
# 200
# japan
# driver
# men
# temperatures
# crackdown
# dead
# five
# night
# stormed
# scandal
# another
# europe
# pushing
# part
# competing
# passenger
# southern
# historical
# 000
# donald
# incident
# turkey
# site
# tariffs
# with
# keeladi
# wrote
# featuring
# taking
# vigil
# until
# behind
# policy
# hostilities
# lehrer
# trump
# rail
# crops
# trained
# fuelling
# one
# given
# investigating
# due
# ----------- FEED 0 -----------
# china
# would
# new
# scientific
# orbit
# internet
# federal
# have
# providing
# from
# signed
# into
# earth
# data
# which
# its
# this
# just
# space
# race
# satellites
# government
# had
# used
# with
# women
# low
# trump
